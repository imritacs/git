# %%
import pandas as pd
from pandas_profiling import ProfileReport 
import numpy as np
from sklearn import metrics
import matplotlib.pyplot as plt 
plt.rc("font", size=14)
import seaborn as sns
sns.set(style="white")
sns.set(style="whitegrid", color_codes=True)

# %%
train_data=pd.read_csv('C:/Users/Rita/Desktop/New folder/GENDER RECOGNITION BY VOICE/voice_train.csv')
print('Data Shape:', train_data.shape)
train_data.head()
# Out:
# Data Shape: (2851, 22)
#      Id  meanfreq        sd    median       Q25       Q75       IQR      skew  \
# 0   765  0.162337  0.058206  0.174065  0.100225  0.196512  0.096287  2.127226
# 1  3071  0.161653  0.057435  0.170138  0.157522  0.182929  0.025407  6.968850
# 2  1546  0.165290  0.061891  0.135071  0.118468  0.225176  0.106708  2.631865
# 3   410  0.188100  0.055735  0.206028  0.130493  0.229470  0.098977  1.538406
# 4  2689  0.187497  0.044226  0.190071  0.156800  0.215435  0.058635  1.653083
#
#         kurt    sp.ent  ...  centroid   meanfun    minfun    maxfun   meandom  \
# 0   7.815129  0.921533  ...  0.162337  0.095852  0.016754  0.235294  0.406033
# 1  60.968047  0.870409  ...  0.161653  0.163486  0.015601  0.204082  0.595161
# 2  12.629116  0.918897  ...  0.165290  0.120050  0.035088  0.222222  0.458577
# 3   5.145753  0.914325  ...  0.188100  0.108470  0.021305  0.145455  0.493229
# 4   5.839465  0.907477  ...  0.187497  0.154529  0.048338  0.279070  1.113502
#
# ...

# %%
train_data.describe()
# Out:
#                 Id     meanfreq           sd       median          Q25  \
# count  2851.000000  2851.000000  2851.000000  2851.000000  2851.000000
# mean   1591.565416     0.180923     0.057143     0.185722     0.140349
# std     909.939169     0.029796     0.016588     0.036175     0.048628
# min       1.000000     0.039363     0.018363     0.010975     0.000229
# 25%     808.500000     0.163739     0.042082     0.169726     0.111139
# 50%    1590.000000     0.184848     0.059151     0.190067     0.140229
# 75%    2382.500000     0.199061     0.066891     0.210650     0.175690
# max    3167.000000     0.251124     0.115273     0.261224     0.247347
#
#                Q75          IQR         skew         kurt       sp.ent  ...  \
# count  2851.000000  2851.000000  2851.000000  2851.000000  2851.000000  ...
# mean      0.224730     0.084381     3.118469    35.808329     0.895312  ...
# std       0.023509     0.042728     4.163727   131.430900     0.044795  ...
# ...

# %%
test_data=pd.read_csv('C:/Users/Rita/Desktop/New folder/GENDER RECOGNITION BY VOICE/voice_test.csv')
print('Data Shape:', test_data.shape)
test_data.head()
# Out:
# Data Shape: (317, 21)
#      Id  meanfreq        sd    median       Q25       Q75       IQR      skew  \
# 0  2148  0.186833  0.027472  0.184325  0.173955  0.204731  0.030777  2.655225
# 1  1124  0.188879  0.060316  0.195537  0.138072  0.242975  0.104904  1.497393
# 2   170  0.150705  0.087127  0.174299  0.069666  0.226082  0.156416  2.603951
# 3  3158  0.183667  0.040607  0.182534  0.156480  0.207646  0.051166  2.054138
# 4  2229  0.205159  0.039543  0.210805  0.186667  0.228908  0.042241  2.099683
#
#         kurt    sp.ent  ...      mode  centroid   meanfun    minfun    maxfun  \
# 0  10.565846  0.821812  ...  0.180645  0.186833  0.172790  0.023495  0.271186
# 1   5.037085  0.909425  ...  0.140386  0.188879  0.133092  0.050847  0.272727
# 2  22.328899  0.969287  ...  0.050181  0.150705  0.109992  0.017260  0.266667
# 3   7.483019  0.898138  ...  0.177040  0.183667  0.149237  0.018648  0.262295
# 4   7.562209  0.876002  ...  0.224885  0.205159  0.154736  0.047105  0.277457
#
# ...

# %%
profile = ProfileReport(df = train_data)
profile.to_file(output_file = 'Pre-Profiling Report.html')
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
y = train_data["label"]
y
# Out:
# 0         male
# 1       female
# 2         male
# 3         male
# 4       female
#          ...
# 2846    female
# 2847      male
# 2848      male
# 2849      male
# 2850      male
# Name: label, Length: 2851, dtype: object

# %%
X = train_data.drop(['label'], axis=1)
X.head()
# Out:
#      Id  meanfreq        sd    median       Q25       Q75       IQR      skew  \
# 0   765  0.162337  0.058206  0.174065  0.100225  0.196512  0.096287  2.127226
# 1  3071  0.161653  0.057435  0.170138  0.157522  0.182929  0.025407  6.968850
# 2  1546  0.165290  0.061891  0.135071  0.118468  0.225176  0.106708  2.631865
# 3   410  0.188100  0.055735  0.206028  0.130493  0.229470  0.098977  1.538406
# 4  2689  0.187497  0.044226  0.190071  0.156800  0.215435  0.058635  1.653083
#
#         kurt    sp.ent  ...      mode  centroid   meanfun    minfun    maxfun  \
# 0   7.815129  0.921533  ...  0.195134  0.162337  0.095852  0.016754  0.235294
# 1  60.968047  0.870409  ...  0.171014  0.161653  0.163486  0.015601  0.204082
# 2  12.629116  0.918897  ...  0.129191  0.165290  0.120050  0.035088  0.222222
# 3   5.145753  0.914325  ...  0.222698  0.188100  0.108470  0.021305  0.145455
# 4   5.839465  0.907477  ...  0.196000  0.187497  0.154529  0.048338  0.279070
#
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=0)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (2280, 21)
# (2280,)
# (571, 21)
# (571,)

# %%
from sklearn.linear_model import LogisticRegression
model_lr = LogisticRegression(random_state = 1)
model_lr.fit(X_train,y_train)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(random_state=1)

# %%
y_pred_lr=model_lr.predict(X_test)

# %%
y_pred_lr
# Out:
# array(['male', 'male', 'female', 'female', 'female', 'female', 'female',
#        'female', 'female', 'female', 'male', 'male', 'male', 'male',
#        'male', 'female', 'male', 'male', 'male', 'male', 'female',
#        'female', 'male', 'male', 'male', 'female', 'male', 'male',
#        'female', 'male', 'male', 'female', 'female', 'male', 'male',
#        'female', 'female', 'female', 'male', 'female', 'male', 'male',
#        'female', 'male', 'female', 'male', 'female', 'male', 'male',
#        'female', 'male', 'male', 'male', 'female', 'male', 'male',
#        'female', 'male', 'male', 'male', 'male', 'female', 'female',
#        'male', 'female', 'female', 'female', 'male', 'male', 'female',
#        'female', 'female', 'male', 'female', 'female', 'male', 'female',
#        'male', 'male', 'male', 'male', 'male', 'male', 'male', 'female',
#        'female', 'male', 'male', 'female', 'male', 'female', 'female',
# ...

# %%
x_pred_lr=model_lr.predict(X_train)
y_pred_lr=model_lr.predict(X_test)

# %%
prediction_lr1 = pd.DataFrame()
prediction1_lr1 = model_rf.predict(test_data)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix
accuracy_train = accuracy_score(y_train,x_pred_lr)
accuracy_test = accuracy_score(y_test,y_pred_lr)
print('Accuracy score for train data:', accuracy_train)
print('Accuracy score for test data:', accuracy_test)
# Out:
# Accuracy score for train data: 0.9824561403508771
# Accuracy score for test data: 0.9807355516637478

# %%
from sklearn.ensemble import RandomForestClassifier
model_rf = RandomForestClassifier(random_state = 0)
model_rf.fit(X_train,y_train)
# Out:
# RandomForestClassifier(random_state=0)

# %%
prediction_rf = pd.DataFrame()
prediction_rf = model_rf.predict(X_test)

# %%
prediction_rf1 = pd.DataFrame()
prediction1_rf1 = model_rf.predict(test_data)

# %%
x_pred_rf = model_rf.predict(X_train)
y_pred_rf = model_rf.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix
accuracy_train = accuracy_score(y_train,x_pred_rf)
accuracy_test = accuracy_score(y_test,y_pred_rf)
print('Accuracy score for train data:', accuracy_train)
print('Accuracy score for test data:', accuracy_test)
# Out:
# Accuracy score for train data: 1.0
# Accuracy score for test data: 1.0

# %%
# Decision tree
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier(max_depth=10).fit(X_train,y_train)
predict = model.predict(X_test)
print(X_test['Id'],predict)
model_dt = DecisionTreeClassifier(random_state = 1)
model_dt.fit(X_train,y_train)
# Out:
# 793      349
# 179     1491
# 667     2083
# 601     1789
# 652     2579
#         ...
# 935     2472
# 351      350
# 2780    3073
# 731     1204
# 1477     721
# Name: Id, Length: 571, dtype: int64 ['male' 'male' 'female' 'female' 'female' 'female' 'female' 'female'
#  'female' 'female' 'male' 'male' 'male' 'male' 'male' 'female' 'male'
#  'male' 'male' 'male' 'female' 'female' 'male' 'male' 'male' 'female'
#  'male' 'male' 'female' 'male' 'male' 'female' 'female' 'male' 'male'
#  'female' 'female' 'female' 'male' 'female' 'male' 'male' 'female' 'male'
#  'female' 'male' 'female' 'male' 'male' 'female' 'male' 'male' 'male'
#  'female' 'male' 'male' 'female' 'male' 'male' 'male' 'male' 'female'
#  'female' 'male' 'female' 'female' 'female' 'male' 'male' 'female'
#  'female' 'female' 'male' 'female' 'female' 'male' 'female' 'male' 'male'
#  'male' 'male' 'male' 'male' 'female' 'female' 'female' 'male' 'male'
#  'female' 'male' 'female' 'female' 'female' 'female' 'male' 'female'
# ...

# %%
predict = model.predict(test_data)
pred=pd.DataFrame(predict)
x_pred_dt=model.predict(X_train)
y_pred_dt=model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix
accuracy_train = accuracy_score(y_train,x_pred_dt)
accuracy_test = accuracy_score(y_test,y_pred_dt)
print('Accuracy score for train data:', accuracy_train)
print('Accuracy score for test data:', accuracy_test)
# Out:
# Accuracy score for train data: 1.0
# Accuracy score for test data: 1.0

# %%
c_matrix_train = pd.DataFrame(confusion_matrix(y_test, y_pred_dt))
c_matrix_train.index = ['female','male']
c_matrix_train.columns = ['female','male']
print("Confusion Mateix for RF for Test set\n",c_matrix_train)
# Out:
# Confusion Mateix for RF for Train set
#          female  male
# female     288     0
# male         0   283

# %%
c_matrix_train = pd.DataFrame(confusion_matrix(y_train, y_train))
c_matrix_train.index = ['female','male']
c_matrix_train.columns = ['female','male']
print("Confusion Mateix for RF for Test set\n",c_matrix_train)
# Out:
# Confusion Mateix for RF for Test set
#          female  male
# female    1144     0
# male         0  1136

# %%
from sklearn.metrics import f1_score
print('F1_score for test data using RF is:',f1_score(y_test, y_pred_rf,pos_label='male'))
print('F1_score for test data using LR is:',f1_score(y_test, y_pred_lr,pos_label='male'))
print('F1_score for test data using DT is:',f1_score(y_test, y_pred_dt,pos_label='male'))
# Out:
# F1_score for test data using RF is: 1.0
# F1_score for test data using LR is: 0.9803921568627452
# F1_score for test data using DT is: 1.0

# %%
from sklearn.metrics import recall_score
print('Recall score for test data using RF is:',recall_score(y_test,y_pred_rf,pos_label='male'))   
print('Recall score for test data using LR is:',recall_score(y_test,y_pred_lr,pos_label='male'))
print('Recall score for test data using DT is:',recall_score(y_test,y_pred_dt,pos_label='male'))
# Out:
# Recall score for test data using RF is: 1.0
# Recall score for test data using LR is: 0.9717314487632509
# Recall score for test data using DT is: 1.0

# %%
predic = pd.DataFrame(prediction1_rf1,test_data.Id,columns=['predict']).to_csv('data2.csv',header=False)

# %%
predic = pd.DataFrame(predict,test_data.Id,columns=['predict']).to_csv('data.csv',header=False)
predic = pd.DataFrame(prediction1_lr1,test_data.Id,columns=['predict']).to_csv('data1.csv',header=False)
